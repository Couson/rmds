# %%
import numpy
import pandas as pd

# %%
detail_path = './rmds_q3_competition/competition_data/Q3_competition_detail_dataset.xlsx'
review_path = './rmds_q3_competition/competition_data/Q3_competition_review_dataset.xlsx'

# %% [markdown]
# # 1. Framing
# - improve restaurant performance
# - topic (covid data/ covid density)
#     - 1.covid-19 map: viz covid-19 rate and restaurant locations on the map
#     - 2.covid-19 density over time + revenue pred: would people prefer to eat outside (dine-in & pickup) more? Does the percentage of people who choose dine-in/pick-up change during the pandemic
#     - 3.should restaurant choose to offer deliver or dine-in options for thei customers?
# - data
#     - covid data
#     - covid density
#     - yelp api (transaction)
# - modules

# %% [markdown]
# # 2. EDA

# %% [markdown]
# # 3. Distribution

# %%
detail_df = pd.read_excel(detail_path)
detail_df.head(3).T
# Out:
#                                                                 0  \
# id                                         nzgC5hhlnSq2DYbJbtH5MQ
# name                                  Foxy's Landing & Restaurant
# is_claimed                                                   True
# is_closed                                                   False
# phone                                                 1.66195e+10
# review_count                                                   52
# categories01                                     breakfast_brunch
# categories02                                         tradamerican
# categories03                                                  NaN
# rating                                                          4
# price                                                          $$
# transactions                                                   []
# zip_code                                                    93536
# ...

# %%
detail_df.loc[detail_df.transactions != '[]', :].shape
# Out:
# (7818, 21)

# %%
detail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10710 entries, 0 to 10709
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10710 non-null  object
#  1   name            10710 non-null  object
#  2   is_claimed      10710 non-null  bool
#  3   is_closed       10710 non-null  bool
#  4   phone           9993 non-null   float64
#  5   review_count    10710 non-null  int64
#  6   categories01    10710 non-null  object
#  7   categories02    7434 non-null   object
#  8   categories03    4034 non-null   object
#  9   rating          10710 non-null  float64
#  10  price           8374 non-null   object
#  11  transactions    10710 non-null  object
#  12  zip_code        10703 non-null  float64
#  13  city            10710 non-null  object
#  14  address         10710 non-null  object
#  15  restaurant_url  10710 non-null  object
#  16  image_url       10350 non-null  object
# ...

# %%
review_df = pd.read_excel(review_path)
review_df.head(3).T
# Out:
#                                                                      0  \
# id                                              cal0Wpupxj9c_AV7WzDXsw
# review_id                                       AyueC5Vq_5lUKJFqSzXWWw
# review_text          Slightly turned off by the hostess. She wasn't...
# review_rating                                                        3
# review_time_created                                2021-07-13 15:01:59
#
#                                                                      1  \
# id                                              cal0Wpupxj9c_AV7WzDXsw
# review_id                                       yaH4AmHUz9b3Ywv4VtvU5g
# review_text          Wish I would have known about no brunch at the...
# review_rating                                                        3
# review_time_created                                2021-07-06 13:50:42
#
#                                                                      2
# ...

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32238 entries, 0 to 32237
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   32232 non-null  object
#  1   review_id            30753 non-null  object
#  2   review_text          30753 non-null  object
#  3   review_rating        30753 non-null  float64
#  4   review_time_created  30753 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 1.2+ MB
